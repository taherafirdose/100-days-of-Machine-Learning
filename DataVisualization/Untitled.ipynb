# %%
import plotly.graph_objects as go
import numpy as np
import pandas as pd
import plotly.express as px

# %%
fees=pd.read_csv('fees.csv')

# %%
fees.tail()
# Out:
#       REF_DATE               GEO        DGUID               Level of study  \
# 763  2022/2023  British Columbia  2016A000259       International graduate
# 764  2022/2023             Yukon  2016A000260       Canadian undergraduate
# 765  2022/2023             Yukon  2016A000260            Canadian graduate
# 766  2022/2023             Yukon  2016A000260  International undergraduate
# 767  2022/2023             Yukon  2016A000260       International graduate
#
#                   UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR  \
# 763  Constant dollars     370         units          0  v1411954068
# 764  Constant dollars     370         units          0  v1411954069
# 765  Constant dollars     370         units          0  v1411954070
# 766  Constant dollars     370         units          0  v1411954071
# 767  Constant dollars     370         units          0  v1411954072
#
#      COORDINATE    VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# ...

# %%
fees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REF_DATE        768 non-null    object
#  1   GEO             768 non-null    object
#  2   DGUID           768 non-null    object
#  3   Level of study  768 non-null    object
#  4   UOM             768 non-null    object
#  5   UOM_ID          768 non-null    int64
#  6   SCALAR_FACTOR   768 non-null    object
#  7   SCALAR_ID       768 non-null    int64
#  8   VECTOR          768 non-null    object
#  9   COORDINATE      768 non-null    float64
#  10  VALUE           753 non-null    float64
#  11  STATUS          15 non-null     object
#  12  SYMBOL          0 non-null      float64
#  13  TERMINATED      0 non-null      float64
#  14  DECIMALS        768 non-null    int64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 90.1+ KB

# %%
fees['year']=fees['REF_DATE'].str.split('/').str.get(0)

# %%
fees.tail()
# Out:
#       REF_DATE               GEO        DGUID               Level of study  \
# 763  2022/2023  British Columbia  2016A000259       International graduate
# 764  2022/2023             Yukon  2016A000260       Canadian undergraduate
# 765  2022/2023             Yukon  2016A000260            Canadian graduate
# 766  2022/2023             Yukon  2016A000260  International undergraduate
# 767  2022/2023             Yukon  2016A000260       International graduate
#
#                   UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR  \
# 763  Constant dollars     370         units          0  v1411954068
# 764  Constant dollars     370         units          0  v1411954069
# 765  Constant dollars     370         units          0  v1411954070
# 766  Constant dollars     370         units          0  v1411954071
# 767  Constant dollars     370         units          0  v1411954072
#
#      COORDINATE    VALUE STATUS  SYMBOL  TERMINATED  DECIMALS  year
# ...

# %%
fees.drop(columns=['DGUID','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis=1,inplace=True)

# %%
fees.tail()
# Out:
#       REF_DATE               GEO               Level of study  \
# 763  2022/2023  British Columbia       International graduate
# 764  2022/2023             Yukon       Canadian undergraduate
# 765  2022/2023             Yukon            Canadian graduate
# 766  2022/2023             Yukon  International undergraduate
# 767  2022/2023             Yukon       International graduate
#
#                   UOM    VALUE  year
# 763  Constant dollars  20628.0  2022
# 764  Constant dollars   3983.0  2022
# 765  Constant dollars      NaN  2022
# 766  Constant dollars      NaN  2022
# 767  Constant dollars      NaN  2022

# %%
fees.
# Out:
#      REF_DATE    GEO  Level of study    UOM  VALUE   year
# 0       False  False           False  False  False  False
# 1       False  False           False  False  False  False
# 2       False  False           False  False  False  False
# 3       False  False           False  False  False  False
# 4       False  False           False  False  False  False
# ..        ...    ...             ...    ...    ...    ...
# 763     False  False           False  False  False  False
# 764     False  False           False  False  False  False
# 765     False  False           False  False   True  False
# 766     False  False           False  False   True  False
# 767     False  False           False  False   True  False
#
# [768 rows x 6 columns]
