# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('placement.csv')

# %%
df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
df.describe().transpose()
# Out:
#                        count      mean        std   min    25%    50%    75%  \
# cgpa                  1000.0   6.96124   0.615898  4.89   6.55   6.96   7.37
# placement_exam_marks  1000.0  32.22500  19.130822  0.00  17.00  28.00  44.00
# placed                1000.0   0.48900   0.500129  0.00   0.00   0.00   1.00
#
#                          max
# cgpa                    9.12
# placement_exam_marks  100.00
# placed                  1.00

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'])

plt.subplot(1,2,2)
sns.distplot(df['placement_exam_marks'])

plt.show()
# Out:
# C:\Users\Alina\AppData\Local\Temp\ipykernel_22632\3792736820.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# C:\Users\Alina\AppData\Local\Temp\ipykernel_22632\3792736820.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
plt.figure(figsize=(16,5))


plt.subplot(1,2,2)
sns.distplot(df['placement_exam_marks'])

plt.show()
# Out:
# C:\Users\Alina\AppData\Local\Temp\ipykernel_22632\1088925822.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])

# %%
print('The min value in placement_exam_marks column', df['placement_exam_marks'].min())
print('The max value in placement_exam_marks column', df['placement_exam_marks'].max())
print('The max value in placement_exam_marks column', df['placement_exam_marks'].mean())
print('The max value in placement_exam_marks column', df['placement_exam_marks'].std())
# Out:
# The min value in placement_exam_marks column 0.0
# The max value in placement_exam_marks column 100.0
# The max value in placement_exam_marks column 32.225
# The max value in placement_exam_marks column 19.13082233892108

# %%
percentile25=df['placement_exam_marks'].quantile(0.25)
print(percentile25)
# Out:
# 17.0

# %%
percentile75=df['placement_exam_marks'].quantile(0.75)
print(percentile25)
# Out:
# 17.0

# %%
iqr= percentile75 - percentile25
print(iqr)
# Out:
# 27.0

# %%
upperlim= percentile25 + 1.5*iqr
lowerlim= percentile25 - 1.5*iqr

print('Upper limit is :', upperlim)
print('Lower limit is :', lowerlim)
# Out:
# Upper limit is : 57.5
# Lower limit is : -23.5

# %%
df[df['placement_exam_marks'] > upperlim]
# Out:
#      cgpa  placement_exam_marks  placed
# 9    7.75                  94.0       1
# 25   6.28                  58.0       1
# 40   6.60                  86.0       1
# 42   7.46                  71.0       1
# 43   7.85                  63.0       0
# ..    ...                   ...     ...
# 966  6.24                  72.0       1
# 967  7.35                  59.0       0
# 987  6.77                  62.0       0
# 994  6.48                  63.0       0
# 996  9.12                  65.0       1
#
# [114 rows x 3 columns]

# %%
df[df['placement_exam_marks'] < lowerlim]
# Out:
# Empty DataFrame
# Columns: [cgpa, placement_exam_marks, placed]
# Index: []

# %%
#Trimming

new_df= df[(df['placement_exam_marks'] <= upperlim) & (df['placement_exam_marks'] >= lowerlim)]
new_df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 993  6.73                  21.0       1
# 995  8.87                  44.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [886 rows x 3 columns]

# %%
# Comparing the plots

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['placement_exam_marks'])

plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(2,2,3)
sns.distplot(new_df['placement_exam_marks'])

plt.subplot(2,2,4)
sns.boxplot(new_df['placement_exam_marks'])

plt.show()
# Out:
# C:\Users\Alina\AppData\Local\Temp\ipykernel_22632\3798459719.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# C:\Users\Alina\AppData\Local\Temp\ipykernel_22632\3798459719.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#Capping

cap_df=df.copy()
cap_df['placement_exam_marks']=np.where(df['placement_exam_marks'] > upperlim, upperlim,
                np.where(df['placement_exam_marks'] < lowerlim, lowerlim,
                 df['placement_exam_marks']        
                        ))

# %%
cap_df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  57.5       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
print('The min value in placement_exam_marks column', cap_df['placement_exam_marks'].min())
print('The max value in placement_exam_marks column', cap_df['placement_exam_marks'].max())
# Out:
# The min value in placement_exam_marks column 0.0
# The max value in placement_exam_marks column 57.5

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['placement_exam_marks'])

plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(2,2,3)
sns.distplot(cap_df['placement_exam_marks'])

plt.subplot(2,2,4)
sns.boxplot(cap_df['placement_exam_marks'])

plt.show()
# Out:
# C:\Users\Alina\AppData\Local\Temp\ipykernel_22632\961786367.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# C:\Users\Alina\AppData\Local\Temp\ipykernel_22632\961786367.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
